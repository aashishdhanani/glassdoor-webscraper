# %%
import requests
from bs4 import BeautifulSoup as soup

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8',
    'Referer': 'https://www.google.com/',
    'Connection': 'keep-alive',
}

# %%
html = requests.get('https://www.glassdoor.co.in/Reviews/index.htm', headers=headers)
html.status_code
# Out:
# 200

# %%
bsobj = soup(html.content, 'html.parser')
bsobj
# Out:
# <!DOCTYPE html>
# <html lang="en" style="height: 100%;" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/"><head><link href="/explore/static/css/gd-companyExplorer.29279.css" media="all" rel="stylesheet"/><meta charset="utf-8"/><meta content="origin" name="referrer"/><meta content="#0caa41" name="theme-color"/><meta content="#0caa41" name="msapplication-navbutton-color"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="#0caa41" name="apple-mobile-web-app-status-bar-style"/><meta content="no-cache,must-revalidate" http-equiv="Cache-Control"/><meta content="no-cache" http-equiv="Pragma"/><meta content="0" http-equiv="Expires"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><meta content="nocache" name="Bingbot"/><link href="/manifest.json" rel="manifest"/><link href="/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/><link href="/favicon.ico" rel="icon" type="image/x-icon"/><link crossorigin="true" href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://fonts.googleapis.com" rel="preconnect"/><link href="https://connect.facebook.net" rel="preconnect"/><link href="https://www.facebook.com" rel="preconnect"/><link href="https://www.googletagmanager.com" rel="preconnect"/><link href="https://cdnjs.cloudflare.com" rel="preconnect"/><link as="font" crossorigin="true" href="https://www.glassdoor.com/assets/fonts/GlassdoorSans-Regular.woff2?v=20240110" rel="preload" type="font/woff2"/><link href="/garnish/static/css/gd-core.bundle.6cc45.css" rel="stylesheet"/><link href="/garnish/static/css/gd-vendor.bundle.1a1c4.css" rel="stylesheet"/><link href="/garnish/static/css/gd-globalNav.bundle.33f42.css" rel="stylesheet"/><script src="https://unpkg.com/@dotlottie/player-component@2.7.6/dist/dotlottie-player.mjs" type="module"></script><style>
#                     /* Glassdoor Sans Initial */
#                     @font-face {
#                         font-family: 'Glassdoor Sans Initial';
#                         src: url('https://www.glassdoor.com/assets/fonts/GlassdoorSans-Regular.woff2?v=20240110') format('woff2');
#                         font-display: swap;
#                     }
#
#                     /* Glassdoor Sans */
#                     /* These fonts are loaded after the initial font for performance reasons */
#
#                     @font-face {
#                         font-family: 'Glassdoor Sans';
#                         src: url('https://www.glassdoor.com/assets/fonts/GlassdoorSans-Regular.woff2?v=20240110') format('woff2');
#                         font-weight: 400;
#                         font-display: swap;
#                     }
#
#                     @font-face {
#                         font-family: 'Glassdoor Sans';
#                         src: url('https://www.glassdoor.com/assets/fonts/GlassdoorSans-Semibold.woff2?v=20240110') format('woff2');
#                         font-weight: 600;
#                         font-display: swap;
#                     }
#
#                     @font-face {
#                         font-family: 'Glassdoor Sans';
#                         src: url('https://www.glassdoor.com/assets/fonts/GlassdoorSans-Extrabold.woff2?v=20240110') format('woff2');
#                         font-weight: 800;
#                         font-display: swap;
#                     }
#
#                     :root {
#                         --gd-product-font: 'Glassdoor Sans', 'Glassdoor Sans Initial', sans-serif;
#                         font-family: var(--gd-product-font);
#                         /* This is depreciated but is being used in UI Kit v1 Retrofit so it needs to continue to exist for now */
#                         --gd-product-theme-font: var(--gd-product-font);
#                         --gd-product-theme-rebranded-font: var(--gd-product-theme-font);
#                     }
#                     </style><title data-rh="true">Companies &amp; Reviews | Glassdoor</title><meta content="Companies &amp; Reviews" data-rh="true" property="og:title"/><meta content="Glassdoor - Free company reviews for 2,334,000+ companies. All posted anonymously by employees." data-rh="true" name="description"/><meta content="Glassdoor - Free company reviews for 2,334,000+ companies. All posted anonymously by employees." data-rh="true" property="og:description"/><meta content="Glassdoor" data-rh="true" property="og:site_name"/><meta content="website" data-rh="true" property="og:type"/><meta content="https://www.glassdoor.com/explore/static/images/brand-campaign-image.png" data-rh="true" property="og:image"/><link data-rh="true" datarh="true" href="https://www.glassdoor.co.in/Reviews/index.htm" rel="canonical"/><link data-rh="true" datarh="true" href="https://www.glassdoor.at/Bewertungen/index.htm" hreflang="de-AT" rel="alternate"/><link data-rh="true" datarh="true" href="https://de.glassdoor.ch/Bewertungen/index.htm" hreflang="de-CH" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.de/Bewertungen/index.htm" hreflang="de-DE" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.com.au/Reviews/index.htm" hreflang="en-AU" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.ca/Reviews/index.htm" hreflang="en-CA" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.co.uk/Reviews/index.htm" hreflang="en-GB" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.com.hk/Reviews/index.htm" hreflang="en-HK" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.ie/Reviews/index.htm" hreflang="en-IE" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.co.in/Reviews/index.htm" hreflang="en-IN" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.co.nz/Reviews/index.htm" hreflang="en-NZ" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.sg/Reviews/index.htm" hreflang="en-SG" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.com/Reviews/index.htm" hreflang="en-US" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.com.ar/Evaluaciones/index.htm" hreflang="es-AR" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.es/Opiniones/index.htm" hreflang="es-ES" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.com.mx/Evaluaciones/index.htm" hreflang="es-MX" rel="alternate"/><link data-rh="true" datarh="true" href="https://fr.glassdoor.be/Avis/index.htm" hreflang="fr-BE" rel="alternate"/><link data-rh="true" datarh="true" href="https://fr.glassdoor.ca/Avis/index.htm" hreflang="fr-CA" rel="alternate"/><link data-rh="true" datarh="true" href="https://fr.glassdoor.ch/Avis/index.htm" hreflang="fr-CH" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.fr/Avis/index.htm" hreflang="fr-FR" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.it/Recensioni/index.htm" hreflang="it-IT" rel="alternate"/><link data-rh="true" datarh="true" href="https://nl.glassdoor.be/Reviews/index.htm" hreflang="nl-BE" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.nl/Reviews/index.htm" hreflang="nl-NL" rel="alternate"/><link data-rh="true" datarh="true" href="https://www.glassdoor.com.br/Avaliações/index.htm" hreflang="pt-BR" rel="alternate"/></head><body class="main lang-en en-IN gdGrid" data-locale="en-IN" marginheight="0" marginwidth="0">
# <div id="SkipToLinks"><style data-emotion-css="orbz0e">.css-orbz0e{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:1em;position:absolute;z-index:999;left:-9999px;opacity:0;margin:1em;}.css-orbz0e:focus-within{left:0;opacity:1;}.css-orbz0e a{background:white;padding:.5em;border:2px solid black;border-radius:4px;color:black;}</style><div class="css-orbz0e ebmocqn0"><a href="#">Skip to content</a><a href="#">Skip to footer</a></div></div><div id="UserAlert"></div><header id="SiteNav"><div class="globalNavContainer__globalNavContainerStyles__globalNavContainer" data-test="global-nav-container" id="globalNavContainer"><div class="globalNavContainer__globalNavContainerStyles__mainNav"><div class="globalNavContainer__globalNavContainerStyles__logoContainer globalNavContainer__globalNavContainerStyles__mobileCenterLink"><a aria-label="Glassdoor Home" data-test="global-nav-glassdoor-logo" href="/index.htm" rel="nofollow" target="_top"><span class="globalNavContainer__globalNavContainerStyles__logo" data-test="logo-svg"><svg fill="none" height="36" role="img" width="120" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M115.399 14.355h4.539c.034 0 .062-.03.062-.067V9.812c-.001-1.094-.363-1.984-1.096-2.606-.674-.572-1.686-.917-3.039-.985-.034-.002-.062.027-.062.063v1.688c0 .033.025.06.056.063 1.187.083 2.09.466 2.09 1.8l-2.55.001c-.034 0-.062.03-.062.067v4.386c0 .036.028.066.062.066Zm-98.18 3.623h-5.504c-.086 0-.141.077-.141.153v2.956c0 .093.07.153.141.153h1.955v2.38c0 1.77-.432 2.72-1.955 2.72-1.272 0-2.175-.771-2.175-3.169V16.26c0-2.296.684-3.372 2.199-3.372 1.366 0 1.923.839 1.923 2.406v.89c0 .093.071.152.142.152h3.384c.086 0 .141-.076.141-.152V15.14c.031-3.718-1.947-5.684-5.527-5.684s-5.912 2.127-5.912 6.6v7.395c0 4.405 2.716 6.32 5.731 6.32 3.376 0 5.731-1.33 5.731-6.252v-5.397a.147.147 0 0 0-.133-.152h-.008.008v.008Zm10.536 7.876h-5.292V9.979c0-.094-.07-.153-.141-.153h-3.33c-.086 0-.14.076-.14.153v19.289c0 .093.07.152.14.152h8.755c.086 0 .141-.076.141-.152v-3.253c0-.093-.07-.153-.141-.153h.008v-.008Zm49.73-9.748c0-4.447 2.284-6.616 5.778-6.616 3.447 0 5.763 2.177 5.747 6.616v7.048c0 4.507-2.143 6.582-5.747 6.582s-5.778-2.033-5.778-6.582v-7.048Zm5.778 10.25c1.46 0 2.065-1.067 2.065-3.337v-6.752c0-2.27-.589-3.371-2.065-3.371s-2.065 1.143-2.065 3.371v6.752c0 2.279.605 3.337 2.065 3.337ZM96.195 9.49c-3.494 0-5.779 2.169-5.779 6.616v7.048c0 4.55 2.175 6.582 5.779 6.582s5.747-2.075 5.747-6.582v-7.048c.016-4.439-2.3-6.616-5.747-6.616ZM98.26 23.02c0 2.27-.605 3.337-2.065 3.337s-2.065-1.059-2.065-3.337v-6.752c0-2.228.589-3.371 2.065-3.371s2.065 1.1 2.065 3.371v6.752ZM65.285 9.82h4.993v.017c3.376 0 5.92 1.855 5.92 6.43v6.718c0 4.532-2.481 6.43-5.96 6.43h-4.953c-.071 0-.142-.06-.142-.153V9.99c0-.085.055-.17.142-.17Zm4.797 16.028c1.507 0 2.45-1.034 2.45-3.448l.007.008v-5.887c0-2.44-.989-3.423-2.489-3.423h-1.374v12.75h1.406ZM47.078 9.456h-.055c-3.439 0-5.252 2.118-5.252 5.295 0 3.307 2.136 4.846 3.898 6.115l.341.247.409.297.001.001.001.001c1.244.9 2.204 1.594 2.204 3.123 0 1.28-.785 1.788-1.696 1.813-1.005.025-1.735-.805-1.735-1.847v-1.686a.191.191 0 0 0-.189-.194h-3.219c-.11 0-.188.084-.188.195v1.71c0 3.38 1.9 5.253 5.245 5.253 3.344 0 5.37-1.915 5.37-5.278 0-3.502-2.074-5.015-3.881-6.335l-.06-.044a42.858 42.858 0 0 0-.596-.428c-1.238-.88-2.388-1.697-2.388-2.969 0-1.262.8-1.855 1.727-1.855.998 0 1.704.771 1.704 1.788v1.49c0 .11.087.195.189.195h3.219c.11 0 .188-.084.188-.194V14.7c.008-3.32-1.994-5.227-5.237-5.244Zm11.563 0h.055c3.243.017 5.237 1.923 5.237 5.244v1.449c0 .11-.078.194-.188.194h-3.22a.191.191 0 0 1-.188-.194v-1.491c0-1.017-.706-1.788-1.704-1.788-.926 0-1.727.593-1.727 1.855 0 1.271 1.15 2.089 2.388 2.969.198.14.398.283.596.428l.06.044c1.808 1.32 3.881 2.833 3.881 6.335 0 3.363-2.026 5.278-5.37 5.278-3.345 0-5.245-1.872-5.245-5.252v-1.712c0-.11.079-.194.188-.194h3.22c.102 0 .188.084.188.195V24.5c0 1.042.73 1.872 1.735 1.847.91-.025 1.696-.534 1.696-1.813 0-1.53-.96-2.223-2.203-3.123-.134- ...
#   var url = decodeURIComponent(originalUrl);
#   var result = {
#     params: {},
#     helpers: {
#       generateMessageString: generateMessageString
#     }
#   };
#   var getTitleCase = function getTitleCase(data) {
#     return data.replace(/-/g, ' ').replace(/\w\S*/g, function (txt) {
#       return txt.charAt(0).toUpperCase() + txt.substring(1).toLowerCase();
#     });
#   };
#
#   // https://www.glassdoor.com/Explore/top-companies-seattle_IL.14,21_IC1150505.htm
#   var genericUrlPatternRegex = /\/(?:Explore|Decouvrir|Buscar|Entdecken|Ontdekken|Cerca|Explorar)\/(?:([^_]+))_?(\S*)?.htm/;
#   var paramsRegex = /(?:(IS|II|IL|IO|ID|IF)\.(\d+),(\d+))|(?:(ISEC|IOCC|IDEPT|IIND|IFID)(\d+))|((?:I(M|N|C|S])))(\d+)/g;
#   var urlMatches = genericUrlPatternRegex.exec(url);
#   if (!urlMatches) return result;
#   result.url = url;
#   var _urlMatches = (0, _slicedToArray2["default"])(urlMatches, 3),
#     keywords = _urlMatches[1],
#     params = _urlMatches[2];
#   if (params) {
#     var matches = params.matchAll(paramsRegex);
#     // eslint-disable-next-line no-restricted-syntax
#     var _iterator = _createForOfIteratorHelper(matches),
#       _step;
#     try {
#       for (_iterator.s(); !(_step = _iterator.n()).done;) {
#         var match = _step.value;
#         var groups = match.filter(function (group) {
#           return group;
#         });
#         var _groups = (0, _slicedToArray2["default"])(groups, 4),
#           param = _groups[1],
#           part1 = _groups[2],
#           part2 = _groups[3];
#         var containsSubstring = !Number.isNaN(Number(part1)) && !Number.isNaN(Number(part2));
#         var isLocType = isLocationType(param);
#         var isCustomkey = param === 'IS' && containsSubstring;
#         var key = isCustomkey ? "C".concat(param) : param;
#         var val = void 0;
#         if (containsSubstring) {
#           val = getTitleCase(keywords.substring(part1, part2));
#         } else {
#           val = isLocType ? Number(part2) : Number(part1);
#         }
#         if (!isCustomkey && isLocType) {
#           result.params.locationType = part1;
#         }
#         result.params[urlParamMap[key]] = val;
#       }
#     } catch (err) {
#       _iterator.e(err);
#     } finally {
#       _iterator.f();
#     }
#   }
#   return result;
# }],"generators":{"title":function title(_ref2, format) {
#       var _extractedData$initDa, _extractedData$initDa2, _seoConfig$parsedData2, _seoConfig$parsedData3;
#       var extractedData = _ref2.extractedData,
#         seoConfig = _ref2.seoConfig,
#         appData = _ref2.appData;
#       var location = (extractedData === null || extractedData === void 0 ? void 0 : (_extractedData$initDa = extractedData.initData) === null || _extractedData$initDa === void 0 ? void 0 : (_extractedData$initDa2 = _extractedData$initDa.location) === null || _extractedData$initDa2 === void 0 ? void 0 : _extractedData$initDa2.locationName) || seoConfig.parsedData.params.location || '';
#       var _seoConfig$parsedData = seoConfig.parsedData.params,
#         occ = _seoConfig$parsedData.occ,
#         department = _seoConfig$parsedData.department,
#         sector = _seoConfig$parsedData.sector,
#         industry = _seoConfig$parsedData.industry;
#       var _ref3 = appData || {},
#         filter = _ref3.filter,
#         isDeiFilter = _ref3.isDeiFilter,
#         isCompanyDiscoverPage = _ref3.isCompanyDiscoverPage,
#         appSector = _ref3.sector,
#         appIndustry = _ref3.industry,
#         appLocation = _ref3.location;
#       return seoConfig === null || seoConfig === void 0 ? void 0 : (_seoConfig$parsedData2 = seoConfig.parsedData) === null || _seoConfig$parsedData2 === void 0 ? void 0 : (_seoConfig$parsedData3 = _seoConfig$parsedData2.helpers) === null || _seoConfig$parsedData3 === void 0 ? void 0 : _seoConfig$parsedData3.generateMessageString({
#         location: appLocation || location,
#         filter: filter,
#         isDeiFilter: isDeiFilter,
#         isCompanyDiscoverPage: isCompanyDiscoverPage,
#         occ: occ,
#         department: department,
#         sector: appSector || sector,
#         industry: appIndustry || industry
#       }, format, 'title');
#     },"meta":function meta(_ref4, format) {
#       var _extractedData$initDa3, _extractedData$initDa4, _seoConfig$parsedData5, _seoConfig$parsedData6;
#       var extractedData = _ref4.extractedData,
#         seoConfig = _ref4.seoConfig,
#         appData = _ref4.appData;
#       var location = (extractedData === null || extractedData === void 0 ? void 0 : (_extractedData$initDa3 = extractedData.initData) === null || _extractedData$initDa3 === void 0 ? void 0 : (_extractedData$initDa4 = _extractedData$initDa3.location) === null || _extractedData$initDa4 === void 0 ? void 0 : _extractedData$initDa4.locationName) || seoConfig.parsedData.params.location || '';
#       var _seoConfig$parsedData4 = seoConfig.parsedData.params,
#         occ = _seoConfig$parsedData4.occ,
#         department = _seoConfig$parsedData4.department,
#         sector = _seoConfig$parsedData4.sector,
#         industry = _seoConfig$parsedData4.industry;
#       var _ref5 = appData || {},
#         filter = _ref5.filter,
#         isDeiFilter = _ref5.isDeiFilter,
#         isCompanyDiscoverPage = _ref5.isCompanyDiscoverPage,
#         appSector = _ref5.sector,
#         appIndustry = _ref5.industry,
#         appLocation = _ref5.location;
#       return seoConfig === null || seoConfig === void 0 ? void 0 : (_seoConfig$parsedData5 = seoConfig.parsedData) === null || _seoConfig$parsedData5 === void 0 ? void 0 : (_seoConfig$parsedData6 = _seoConfig$parsedData5.helpers) === null || _seoConfig$parsedData6 === void 0 ? void 0 : _seoConfig$parsedData6.generateMessageString({
#         location: appLocation || location,
#         filter: filter,
#         isDeiFilter: isDeiFilter,
#         isCompanyDiscoverPage: isCompanyDiscoverPage,
#         occ: occ,
#         department: department,
#         sector: appSector || sector,
#         industry: appIndustry || industry
#       }, format, 'metaDesc');
#     }},"parsedData":{"params":{},"helpers":{"generateMessageString":function generateMessageString(_ref, format, messageType) {
#   var location = _ref.location,
#     filter = _ref.filter,
#     isDeiFilter = _ref.isDeiFilter,
#     isCompanyDiscoverPage = _ref.isCompanyDiscoverPage,
#     occ = _ref.occ,
#     department = _ref.department,
#     sector = _ref.sector,
#     industry = _ref.industry;
#   if (isCompanyDiscoverPage) {
#     return format("discover.".concat(messageType, ".default"));
#   }
#   if (sector) {
#     if (isDeiFilter) {
#       return format("explore.".concat(messageType, ".sectorDeiFilter"), {
#         sector: sector,
#         filter: filter
#       });
#     }
#     if (department && location && filter) {
#       return format("explore.".concat(messageType, ".sectorOccLocFilter"), {
#         location: location,
#         sector: sector,
#         occ: department,
#         filter: filter
#       });
#     }
#     if (department && location) {
#       return format("explore.".concat(messageType, ".sectorOccLoc"), {
#         location: location,
#         sector: sector,
#         occ: department
#       });
#     }
#     if (occ && location && filter) {
#       return format("explore.".concat(messageType, ".sectorOccLocFilter"), {
#         location: location,
#         sector: sector,
#         occ: occ,
#         filter: filter
#       });
#     }
#     if (occ && location) {
#       return format("explore.".concat(messageType, ".sectorOccLoc"), {
#         location: location,
#         sector: sector,
#         occ: occ
#       });
#     }
#     if (department && filter) {
#       return format("explore.".concat(messageType, ".sectorOccFilter"), {
#         sector: sector,
#         occ: department,
#         filter: filter
#       });
#     }
#     if (department) {
#       return format("explore.".concat(messageType, ".sectorOcc"), {
#         sector: sector,
#         occ: department
#       });
#     }
#     if (occ && filter) {
#       return format("explore.".concat(messageType, ".sectorOccFilter"), {
#         sector: sector,
#         occ: occ,
#         filter: filter
#       });
#     }
#     if (occ) {
#       return format("explore.".concat(messageType, ".sectorOcc"), {
#         sector: sector,
#         occ: occ
#       });
#     }
#     if (location && filter) {
#       return format("explore.".concat(messageType, ".sectorLocationFilter"), {
#         sector: sector,
#         location: location,
#         filter: filter
#       });
#     }
#     if (location) {
#       return format("explore.".concat(messageType, ".sectorLocation"), {
#         sector: sector,
#         location: location
#       });
#     }
#     if (filter) {
#       return format("explore.".concat(messageType, ".sectorFilter"), {
#         sector: sector,
#         filter: filter
#       });
#     }
#     return format("explore.".concat(messageType, ".sector"), {
#       sector: sector
#     });
#   }
#   if (industry) {
#     if (isDeiFilter) {
#       return format("explore.".concat(messageType, ".sectorDeiFilter"), {
#         sector: industry,
#         filter: filter
#       });
#     }
#     if (department && location && filter) {
#       return format("explore.".concat(messageType, ".sectorOccLocFilter"), {
#         sector: industry,
#         location: location,
#         occ: department,
#         filter: filter
#       });
#     }
#     if (department && location) {
#       return format("explore.".concat(messageType, ".sectorOccLoc"), {
#         sector: industry,
#         location: location,
#         occ: department
#       });
#     }
#     if (occ && location && filter) {
#       return format("explore.".concat(messageType, ".sectorOccLocFilter"), {
#         location: location,
#         sector: industry,
#         occ: occ,
#         filter: filter
#       });
#     }
#     if (occ && location) {
#       return format("explore.".concat(messageType, ".sectorOccLoc"), {
#         location: location,
#         sector: industry,
#         occ: occ
#       });
#     }
#     if (department && filter) {
#       return format("explore.".concat(messageType, ".sectorOccFilter"), {
#         sector: industry,
#         occ: department,
#         filter: filter
#       });
#     }
#     if (department) {
#       return format("explore.".concat(messageType, ".sectorOcc"), {
#         sector: industry,
#         occ: department
#       });
#     }
#     if (occ && filter) {
#       return format("explore.".concat(messageType, ".sectorOccFilter"), {
#         sector: industry,
#         occ: occ,
#         filter: filter
#       });
#     }
#     if (occ) {
#       return format("explore.".concat(messageType, ".sectorOcc"), {
#         sector: industry,
#         occ: occ
#       });
#     }
#     if (location && filter) {
#       return format("explore.".concat(messageType, ".sectorLocationFilter"), {
#         sector: industry,
#         location: location,
#         filter: filter
#       });
#     }
#     if (location) {
#       return format("explore.".concat(messageType, ".sectorLocation"), {
#         sector: industry,
#         location: location
#       });
#     }
#     if (filter) {
#       return format("explore.".concat(messageType, ".sectorFilter"), {
#         sector: industry,
#         filter: filter
#       });
#     }
#     return format("explore.".concat(messageType, ".sector"), {
#       sector: industry
#     });
#   }
#   if (occ) {
#     if (isDeiFilter) {
#       return format("explore.".concat(messageType, ".occDeiFilter"), {
#         occ: occ,
#         filter: filter
#       });
#     }
#     if (location && filter) {
#       return format("explore.".concat(messageType, ".occLocationFilter"), {
#         occ: occ,
#         location: location,
#         filter: filter
#       });
#     }
#     if (location) {
#       return format("explore.".concat(messageType, ".occLocation"), {
#         occ: occ,
#         location: location
#       });
#     }
#     if (filter) {
#       return format("explore.".concat(messageType, ".occFilter"), {
#         occ: occ,
#         filter: filter
#       });
#     }
#     return format("explore.".concat(messageType, ".occ"), {
#       occ: occ
#     });
#   }
#   if (department) {
#     if (isDeiFilter) {
#       return format("explore.".concat(messageType, ".occDeiFilter"), {
#         occ: department,
#         filter: filter
#       });
#     }
#     if (location && filter) {
#       return format("explore.".concat(messageType, ".occLocationFilter"), {
#         occ: department,
#         location: location,
#         filter: filter
#       });
#     }
#     if (location) {
#       return format("explore.".concat(messageType, ".occLocation"), {
#         occ: department,
#         location: location
#       });
#     }
#     if (filter) {
#       return format("explore.".concat(messageType, ".occFilter"), {
#         occ: department,
#         filter: filter
#       });
#     }
#     return format("explore.".concat(messageType, ".occ"), {
#       occ: department
#     });
#   }
#   if (location) {
#     if (isDeiFilter) {
#       return format("explore.".concat(messageType, ".locationDeiFilter"), {
#         location: location,
#         filter: filter
#       });
#     }
#     if (filter) {
#       return format("explore.".concat(messageType, ".locationFilter"), {
#         location: location,
#         filter: filter
#       });
#     }
#     return format("explore.".concat(messageType, ".location"), {
#       location: location
#     });
#   }
#   if (filter) {
#     if (isDeiFilter) {
#       return format("explore.".concat(messageType, ".deiFilter"), {
#         filter: filter
#       });
#     }
#     return format("explore.".concat(messageType, ".filter"), {
#       filter: filter
#     });
#   }
#   return format("explore.".concat(messageType, ".default"), {});
# }}},"dos2SEOExperiments":{}},"oz":{"sentry":{"sentryjs_sitediscovery":{}},"companyExplorerI18n":{"gocsEnabled":{"languagesSupported":["eng","fra","deu","spa","ita","nld","por"],"_enabled":true}},"companyExplorer":{"deiFilters":{"tldIdsSupported":[1],"_enabled":true}},"companyDiscover":{"default":{"bptwYear":"2022","tldIdsWithBlog":[1,2,6,7],"tldIdsWithBPTWModule":[1,2],"_enabled":true}},"consumerBlog":{"default":{"enableBlogLinks":false,"enableContentHubLinks":false,"enableMoreFromGlassdoorLinks":false,"includeBlogRightJobLandingPage":false,"includeGenderPayGapLandingPage":false,"includeEmployerBlog":false,"_enabled":true}}},"dos2":{"user_login":{"treatment":"sign_in_hierarchy_t0","experiment":"sign_in_hierarchy_20220517","params":{"signInHierarchy":"t0"}},"site_discovery_fishbowl":{"treatment":"fishbowl_default","experiment":"exp_site_discovery_fishbowl_catchall","params":{"fishbowlMemberHome":"t0"}},"site_discovery_nav":{"treatment":"career_nav_t2","experiment":"site_discovery_nav_t2","params":{"careerNav":"t2"}},"site_discovery_ugc_search2":{"treatment":"ugc_search2_t1","experiment":"PROD_ugc_search2_v1","params":{"ugcSearch2":"true"}},"site_discovery_ugc_search2_autocomplete":{"treatment":"ugc_search2_autocomplete_t1","experiment":"PROD_ugc_search2_autocomplete_v1","params":{"ugcSearch2_autocomplete":"true"}},"site_discovery_ugc_search2_autocomplete_location":{"treatment":"default","experiment":"catch_all","params":{"useUgcLocationAutocompleteService":"true"}},"site_discovery_ugc_search2_interviews":{"treatment":"ugc_search2_interviews_t1","experiment":"PROD_ugc_search2_interviews_v1","params":{"ugcSearch2_interviews":"true"}},"site_discovery_ugc_search2_location":{"treatment":"default","experiment":"catch_all","params":{"useUgcLocationService":"false"}},"site_discovery_ugc_search2_normal_location":{"treatment":"default","experiment":"catch_all","params":{"useUgcLocationNormalService":"true"}},"site_discovery_ugc_search2_salaries":{"treatment":"ugc_search2_salaries_t1","experiment":"PROD_INTL_ugc_search2_salaries_v1","params":{"ugcSearch2_salaries":"true"}},"growth_apple_hfa":{"treatment":"update_user_apple_endpoint_default_t1","experiment":"update_user_apple_endpoint_default_test","params":{"enableSiwaHFA":"true"}},"growth_banner_cookie":{"treatment":"t2","experiment":"cookie_PROD_31072024","params":{"cookieExpires":"1","cookieTreatment":"cookie-t2"}},"growth_banner_cookie_app_install":{"treatment":"t1","experiment":"cookie_PROD","params":{"cookieExpiresAppInstall":"1","cookieTreatmentAppInstall":"cookie-app-install-t1"}},"growth_facebook_hfa":{"treatment":"update_user_facebook_endpoint_default_t1","experiment":"PROD_update_user_facebook_endpoint_default_test","params":{"enableFacebookHFA":"true"}},"growth_facebook_link_hfa":{"treatment":"update_user_facebook_link_endpoint_default_t1","experiment":"PROD_update_user_facebook_link_endpoint_default_test","params":{"enableFacebookLinkHFA":"true"}},"growth_forgot_password_hfa":{"treatment":"update_user_forgot_password_endpoint_default_t1","experiment":"PROD_update_user_forgot_password_endpoint_default_test","params":{"enableForgotPasswordHFA":"true"}},"growth_global":{"treatment":"tng_community_june_15_t1","experiment":"tng_community_june_15_20230620","params":{"inlineAppInstall":"false","showNUFInPeekMode":"true","regToEasyApplyTreatment":"t0","facebookNoIframe":"false","appInstallBannerTreatment":"t0","growthAA":"true","GDPRSignin":"false","paginationV2":"t0","oneTapV2Enabled":"true","singularAuth":"t1","enableSiwa":"false","enableTngFeatures":"true","enableJobsNext":"true"}},"growth_google_hfa":{"treatment":"update_user_google_endpoint_default_t1","experiment":"PROD_update_user_google_endpoint_default_test","params":{"enableGoogleHFA":"true"}},"growth_google_link_hfa":{"treatment":"update_user_google_link_endpoint_default_t1","experiment":"PROD_update_user_google_link_endpoint_default_test","params":{"enableGoogleLinkHFA":"true"}},"growth_header":{"treatment":"search_submit ...
# Visit www.infosys.com to see how Infosys (NYSE: INFY) can help your enterprise navigate your next.
# </p></div></div></div></div><div class="mt-0 mb-std p-std css-mdw3bo css-errlgf" data-brandviews="MODULE:n=explore-companies-results:eid=6036" data-test="employer-card-single"><div class="row d-flex flex-wrap"><div class="col-12 col-lg-8 order-0"><div class="d-flex"><div class="mr-std"><img alt="Amazon" class="employerInfo__EmployerInfoStyles__logoStyle" data-test="employer-logo" src="https://media.glassdoor.com/sql/6036/amazon-squarelogo-1552847650117.png"/></div><div><span class="align-items-center mb-xsm"><h2 data-test="employer-short-name">Amazon</h2><div class="d-flex"><span class="pr-xsm ratingsWidget__RatingsWidgetStyles__rating" data-test="rating"><b>3.7</b></span><style data-emotion="css ojdxng">.css-ojdxng{outline:none;--icon-color-a:var(--deprecated-custom-color, var(--variant-color));--icon-color-b:var(--deprecated-custom-color, var(--variant-color));}.css-ojdxng[data-size-variant='xs']{font-size:var(--gd-component-Star-sizeVariant-xs-fontSize, 0.75rem);}.css-ojdxng[data-size-variant='sm']{font-size:var(--gd-component-Star-sizeVariant-sm-fontSize, 1rem);}.css-ojdxng[data-size-variant='md']{font-size:var(--gd-component-Star-sizeVariant-md-fontSize, 1.5rem);}.css-ojdxng[data-size-variant='lg']{font-size:var(--gd-component-Star-sizeVariant-lg-fontSize, 2.25rem);}.css-ojdxng[data-color-variant='primary']{--variant-color:var(--gd-component-Star-colorVariant-primary-color, var(--gd-theme-color-green-400, #0caa41));}.css-ojdxng[data-color-variant='secondary']{--variant-color:var(--gd-component-Star-colorVariant-secondary-color, var(--gd-theme-color-black, black));}</style><span class="gd-ui-star pr-xsm css-ojdxng efdhmtv0" data-color-variant="primary" data-size-variant="sm" role="presentation"><style data-emotion="css pq72fl">.css-pq72fl{height:1em;width:1em;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}</style><svg aria-hidden="true" class="css-pq72fl e7xsrz90" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><defs><path d="m12 2.694 2.119 6.857.109.352h7.294L15.898 14.2l-.277.212.103.333 2.135 6.909-5.556-4.244-.303-.232-.303.232-5.556 4.244 2.135-6.909.103-.333-.277-.212-5.624-4.296h7.295l.108-.352L12 2.694Z" id="star_svg__star-multicolor-icon-path"></path><clippath id="star_svg__star-multicolor-icon-clip"><use href="#star_svg__star-multicolor-icon-path"></use></clippath></defs><use clip-path="url(#star_svg__star-multicolor-icon-clip)" fill="var(--icon-color-a, currentColor)" href="#star_svg__star-multicolor-icon-path" stroke="var(--icon-color-b, currentColor)" stroke-width="var(--icon-stroke-width, 1px)"></use></svg></span></div></span></div></div></div><div class="col-12 col-lg-4 mt-lg-0 mt-std d-flex justify-content-between order-6 order-lg-1"><a data-test="cell-Reviews-url" href="/Reviews/Amazon-Reviews-E6036.htm" rel="noopener noreferrer" target="_blank"><div class="d-flex flex-column align-items-center" data-test="cell-Reviews"><h3 class="mt-xsm mt-md-0" data-test="cell-Reviews-count">2.1L</h3><div><span class="css-u9lko5 euttuq60">Reviews</span></div></div></a><a data-test="cell-Salaries-url" href="/Salary/Amazon-Salaries-E6036.htm" rel="noopener noreferrer" target="_blank"><div class="d-flex flex-column align-items-center" data-test="cell-Salaries"><h3 class="mt-xsm mt-md-0" data-test="cell-Salaries-count">54.5T</h3><div><span class="css-u9lko5 euttuq60">Salaries</span></div></div></a><a data-test="cell-Jobs-url" href="/Jobs/Amazon-Jobs-E6036.htm" rel="noopener noreferrer" target="_blank"><div class="d-flex flex-column align-items-center" data-test="cell-Jobs"><h3 class="mt-xsm mt-md-0" data-test="cell-Jobs-count">20T</h3><div><span class="css-u9lko5 euttuq60">Jobs</span></div></div></a></div><div class="col-lg-4 mt-xsm mt-sm-std order-2"><span class="css-1xs6sia e1lamatj0"><b>Location</b></span><span class="d-block mt-0 css-56kyx5" data-test="employer-location"><a href="/Location/All-Amazon-Office-Locations-E6036.htm" targe ...
#
# We are driven by the excitement of building technologies, inventing products, and providing services that transform the way our customers live their lives and run their businesses.</p></div></div></div></div><div class="mt-0 mb-std p-std css-mdw3bo css-errlgf" data-brandviews="MODULE:n=explore-companies-results:eid=8014" data-test="employer-card-single"><div class="row d-flex flex-wrap"><div class="col-12 col-lg-8 order-0"><div class="d-flex"><div class="mr-std"><img alt="Cognizant Technology Solutions" class="employerInfo__EmployerInfoStyles__logoStyle" data-test="employer-logo" src="https://media.glassdoor.com/sql/8014/cognizant-technology-solutions-squareLogo-1651131366751.png"/></div><div><span class="align-items-center mb-xsm"><h2 data-test="employer-short-name">Cognizant Technology Solutions</h2><div class="d-flex"><span class="pr-xsm ratingsWidget__RatingsWidgetStyles__rating" data-test="rating"><b>3.7</b></span><style data-emotion="css ojdxng">.css-ojdxng{outline:none;--icon-color-a:var(--deprecated-custom-color, var(--variant-color));--icon-color-b:var(--deprecated-custom-color, var(--variant-color));}.css-ojdxng[data-size-variant='xs']{font-size:var(--gd-component-Star-sizeVariant-xs-fontSize, 0.75rem);}.css-ojdxng[data-size-variant='sm']{font-size:var(--gd-component-Star-sizeVariant-sm-fontSize, 1rem);}.css-ojdxng[data-size-variant='md']{font-size:var(--gd-component-Star-sizeVariant-md-fontSize, 1.5rem);}.css-ojdxng[data-size-variant='lg']{font-size:var(--gd-component-Star-sizeVariant-lg-fontSize, 2.25rem);}.css-ojdxng[data-color-variant='primary']{--variant-color:var(--gd-component-Star-colorVariant-primary-color, var(--gd-theme-color-green-400, #0caa41));}.css-ojdxng[data-color-variant='secondary']{--variant-color:var(--gd-component-Star-colorVariant-secondary-color, var(--gd-theme-color-black, black));}</style><span class="gd-ui-star pr-xsm css-ojdxng efdhmtv0" data-color-variant="primary" data-size-variant="sm" role="presentation"><style data-emotion="css pq72fl">.css-pq72fl{height:1em;width:1em;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}</style><svg aria-hidden="true" class="css-pq72fl e7xsrz90" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><defs><path d="m12 2.694 2.119 6.857.109.352h7.294L15.898 14.2l-.277.212.103.333 2.135 6.909-5.556-4.244-.303-.232-.303.232-5.556 4.244 2.135-6.909.103-.333-.277-.212-5.624-4.296h7.295l.108-.352L12 2.694Z" id="star_svg__star-multicolor-icon-path"></path><clippath id="star_svg__star-multicolor-icon-clip"><use href="#star_svg__star-multicolor-icon-path"></use></clippath></defs><use clip-path="url(#star_svg__star-multicolor-icon-clip)" fill="var(--icon-color-a, currentColor)" href="#star_svg__star-multicolor-icon-path" stroke="var(--icon-color-b, currentColor)" stroke-width="var(--icon-stroke-width, 1px)"></use></svg></span></div></span></div></div></div><div class="col-12 col-lg-4 mt-lg-0 mt-std d-flex justify-content-between order-6 order-lg-1"><a data-test="cell-Reviews-url" href="/Reviews/Cognizant-Technology-Solutions-Reviews-E8014.htm" rel="noopener noreferrer" target="_blank"><div class="d-flex flex-column align-items-center" data-test="cell-Reviews"><h3 class="mt-xsm mt-md-0" data-test="cell-Reviews-count">1.1L</h3><div><span class="css-u9lko5 euttuq60">Reviews</span></div></div></a><a data-test="cell-Salaries-url" href="/Salary/Cognizant-Technology-Solutions-Salaries-E8014.htm" rel="noopener noreferrer" target="_blank"><div class="d-flex flex-column align-items-center" data-test="cell-Salaries"><h3 class="mt-xsm mt-md-0" data-test="cell-Salaries-count">95.7T</h3><div><span class="css-u9lko5 euttuq60">Salaries</span></div></div></a><a data-test="cell-Jobs-url" href="/Jobs/Cognizant-Technology-Solutions-Jobs-E8014.htm" rel="noopener noreferrer" target="_blank"><div class="d-flex flex-column align-items-center" data-test="cell-Jobs"><h3 class="mt-xsm mt-md-0" data-test="cell-Jobs ...
#
# When we’re not advising our clients on the next groundbreaking solution, we’re improving lives by volunteering in our communities, fostering inclusion through our affinity groups and so much more. We don’t just dream of a better way—we make it happen!
#
# At Cognizant, you're empowered to chart your own course aligned with your career and life goals. We are focused on building an inclusive environment where everyone feels welcome, heard and celebrated. </p></div></div></div></div><div class="mt-0 mb-std p-std css-mdw3bo css-errlgf" data-brandviews="MODULE:n=explore-companies-results:eid=2763" data-test="employer-card-single"><div class="row d-flex flex-wrap"><div class="col-12 col-lg-8 order-0"><div class="d-flex"><div class="mr-std"><img alt="Deloitte" class="employerInfo__EmployerInfoStyles__logoStyle" data-test="employer-logo" src="https://media.glassdoor.com/sql/2763/deloitte-squareLogo-1674210308592.png"/></div><div><span class="align-items-center mb-xsm"><h2 data-test="employer-short-name">Deloitte</h2><div class="d-flex"><span class="pr-xsm ratingsWidget__RatingsWidgetStyles__rating" data-test="rating"><b>4.0</b></span><style data-emotion="css ojdxng">.css-ojdxng{outline:none;--icon-color-a:var(--deprecated-custom-color, var(--variant-color));--icon-color-b:var(--deprecated-custom-color, var(--variant-color));}.css-ojdxng[data-size-variant='xs']{font-size:var(--gd-component-Star-sizeVariant-xs-fontSize, 0.75rem);}.css-ojdxng[data-size-variant='sm']{font-size:var(--gd-component-Star-sizeVariant-sm-fontSize, 1rem);}.css-ojdxng[data-size-variant='md']{font-size:var(--gd-component-Star-sizeVariant-md-fontSize, 1.5rem);}.css-ojdxng[data-size-variant='lg']{font-size:var(--gd-component-Star-sizeVariant-lg-fontSize, 2.25rem);}.css-ojdxng[data-color-variant='primary']{--variant-color:var(--gd-component-Star-colorVariant-primary-color, var(--gd-theme-color-green-400, #0caa41));}.css-ojdxng[data-color-variant='secondary']{--variant-color:var(--gd-component-Star-colorVariant-secondary-color, var(--gd-theme-color-black, black));}</style><span class="gd-ui-star pr-xsm css-ojdxng efdhmtv0" data-color-variant="primary" data-size-variant="sm" role="presentation"><style data-emotion="css pq72fl">.css-pq72fl{height:1em;width:1em;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}</style><svg aria-hidden="true" class="css-pq72fl e7xsrz90" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><defs><path d="m12 2.694 2.119 6.857.109.352h7.294L15.898 14.2l-.277.212.103.333 2.135 6.909-5.556-4.244-.303-.232-.303.232-5.556 4.244 2.135-6.909.103-.333-.277-.212-5.624-4.296h7.295l.108-.352L12 2.694Z" id="star_svg__star-multicolor-icon-path"></path><clippath id="star_svg__star-multicolor-icon-clip"><use href="#star_svg__star-multicolor-icon-path"></use></clippath></defs><use clip-path="url(#star_svg__star-multicolor-icon-clip)" fill="var(--icon-color-a, currentColor)" href="#star_svg__star-multicolor-icon-path" stroke="var(--icon-color-b, currentColor)" stroke-width="var(--icon-stroke-width, 1px)"></use></svg></span></div></span></div></div></div><div class="col-12 col-lg-4 mt-lg-0 mt-std d-flex justify-content-between order-6 order-lg-1"><a data-test="cell-Reviews-url" href="/Reviews/Deloitte-Reviews-E2763.htm" rel="noopener noreferrer" target="_blank"><div class="d-flex flex-column align-items-center" data-test="cell-Reviews"><h3 class="mt-xsm mt-md-0" data-test="cell-Reviews-count">1.2L</h3><div><span class="css-u9lko5 euttuq60">Reviews</span></div></div></a><a data-test="cell-Salaries-url" href="/Salary/Deloitte-Salaries-E2763.htm" rel="noopener noreferrer" target="_blank"><div class="d-flex flex-column align-items-center" data-test="cell-Salaries"><h3 class="mt-xsm mt-md-0" data-test="cell-Salaries-count">44.3T</h3><div><span class="css-u9lko5 euttuq60">Salaries</span></div></div></a><a data-test="cell-Jobs-url" href="/Jobs/Deloitte-Jobs-E2763.htm" rel="noopener noreferrer" target="_blank"><div class="d-flex flex-column align-items-center" data-test="cell-Jobs"><h3 class="mt-xsm mt-md-0" data-test="cell-Jobs-count">30.2T</h3><div><span class="css-u9lko5 euttuq60">Jobs</span></div></div></a></div><div class="col-lg-4  ...
#
# Deloitte US-India Offices is part of region within the Deloitte US organization, with offices across seven cities in India — Hyderabad, Mumbai, Delhi-NCR, Bengaluru, Kolkata, Pune and Chennai.</p></div></div></div></div><div class="mt-0 mb-std p-std css-mdw3bo css-errlgf" data-brandviews="MODULE:n=explore-companies-results:eid=3803" data-test="employer-card-single"><div class="row d-flex flex-wrap"><div class="col-12 col-lg-8 order-0"><div class="d-flex"><div class="mr-std"><img alt="Capgemini" class="employerInfo__EmployerInfoStyles__logoStyle" data-test="employer-logo" src="https://media.glassdoor.com/sql/3803/capgemini-squareLogo-1688367853815.png"/></div><div><span class="align-items-center mb-xsm"><h2 data-test="employer-short-name">Capgemini</h2><div class="d-flex"><span class="pr-xsm ratingsWidget__RatingsWidgetStyles__rating" data-test="rating"><b>3.9</b></span><style data-emotion="css ojdxng">.css-ojdxng{outline:none;--icon-color-a:var(--deprecated-custom-color, var(--variant-color));--icon-color-b:var(--deprecated-custom-color, var(--variant-color));}.css-ojdxng[data-size-variant='xs']{font-size:var(--gd-component-Star-sizeVariant-xs-fontSize, 0.75rem);}.css-ojdxng[data-size-variant='sm']{font-size:var(--gd-component-Star-sizeVariant-sm-fontSize, 1rem);}.css-ojdxng[data-size-variant='md']{font-size:var(--gd-component-Star-sizeVariant-md-fontSize, 1.5rem);}.css-ojdxng[data-size-variant='lg']{font-size:var(--gd-component-Star-sizeVariant-lg-fontSize, 2.25rem);}.css-ojdxng[data-color-variant='primary']{--variant-color:var(--gd-component-Star-colorVariant-primary-color, var(--gd-theme-color-green-400, #0caa41));}.css-ojdxng[data-color-variant='secondary']{--variant-color:var(--gd-component-Star-colorVariant-secondary-color, var(--gd-theme-color-black, black));}</style><span class="gd-ui-star pr-xsm css-ojdxng efdhmtv0" data-color-variant="primary" data-size-variant="sm" role="presentation"><style data-emotion="css pq72fl">.css-pq72fl{height:1em;width:1em;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}</style><svg aria-hidden="true" class="css-pq72fl e7xsrz90" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><defs><path d="m12 2.694 2.119 6.857.109.352h7.294L15.898 14.2l-.277.212.103.333 2.135 6.909-5.556-4.244-.303-.232-.303.232-5.556 4.244 2.135-6.909.103-.333-.277-.212-5.624-4.296h7.295l.108-.352L12 2.694Z" id="star_svg__star-multicolor-icon-path"></path><clippath id="star_svg__star-multicolor-icon-clip"><use href="#star_svg__star-multicolor-icon-path"></use></clippath></defs><use clip-path="url(#star_svg__star-multicolor-icon-clip)" fill="var(--icon-color-a, currentColor)" href="#star_svg__star-multicolor-icon-path" stroke="var(--icon-color-b, currentColor)" stroke-width="var(--icon-stroke-width, 1px)"></use></svg></span></div></span></div></div></div><div class="col-12 col-lg-4 mt-lg-0 mt-std d-flex justify-content-between order-6 order-lg-1"><a data-test="cell-Reviews-url" href="/Reviews/Capgemini-Reviews-E3803.htm" rel="noopener noreferrer" target="_blank"><div class="d-flex flex-column align-items-center" data-test="cell-Reviews"><h3 class="mt-xsm mt-md-0" data-test="cell-Reviews-count">84.1T</h3><div><span class="css-u9lko5 euttuq60">Reviews</span></div></div></a><a data-test="cell-Salaries-url" href="/Salary/Capgemini-Salaries-E3803.htm" rel="noopener noreferrer" target="_blank"><div class="d-flex flex-column align-items-center" data-test="cell-Salaries"><h3 class="mt-xsm mt-md-0" data-test="cell-Salaries-count">57T</h3><div><span class="css-u9lko5 euttuq60">Salaries</span></div></div></a><a data-test="cell-Jobs-url" href="/Jobs/Capgemini-Jobs-E3803.htm" rel="noopener noreferrer" target="_blank"><div class="d-flex flex-column align-items-center" data-test="cell-Jobs"><h3 class="mt-xsm mt-md-0" data-test="cell-Jobs-count">5.5T</h3><div><span class="css-u9lko5 euttuq60">Jobs</span></div></div></a></div><div class="col-lg-4 mt-xs ...
#
# ...
# <script defer="" src="/garnish/static/js/gd-runtime.bundle.d74e2.js"></script>
# <script defer="" src="/garnish/static/js/gd-vendor.bundle.b5910.js"></script>
# <script defer="" src="/garnish/static/js/gd-core.bundle.0d700.js"></script>
# </div><script>
# window.GD = window.GD || {}; window.GD.page = window.GD.page || {};
# window.GD.page.userAlertData = {"isEligibleForRestoreAccessAlert":false,"isEligibleForVerifyEmailAlert":false};
# window.GD.page.headerData = {"menu":{"mainMenu":[{"textKey":"site.header.community","link":"/Community/index.htm","target":"_top","gaLabel":"null","testLabel":"site-header-community","id":"community","iconKey":"community","analyticsLabel":"site header community"},{"textKey":"site.header.jobs","link":"/Job/index.htm","target":"_top","gaLabel":"null","testLabel":"site-header-jobs","id":"jobs","iconKey":"jobs","analyticsLabel":"site header jobs"},{"textKey":"site.header.companies","link":"/Reviews/index.htm","target":"_top","gaLabel":"null","testLabel":"site-header-companies","id":"companies","iconKey":"companies","analyticsLabel":"site header companies"},{"textKey":"site.header.salaries","link":"/Salaries/index.htm","target":"_top","gaLabel":"null","testLabel":"site-header-salaries","id":"salaries","iconKey":"salaries","analyticsLabel":"site header salaries"}],"employerMenu":{"id":"primaryEmployerMenu","link":"/employers/","target":"_top","textKey":"site.header.link.employers.alt","tracking":{"CMPGN":"Website - B2C | FEA2 | gdemployermenu","SOURCE":"gdemployermenu","TYPE":"source"},"analyticsLabel":"site header for employers","testLabel":"site-header-for-employers"}},"appData":{"type":"companies","searchKeyword":"","searchLocation":{"name":"","id":0,"type":""},"isCachedPage":false,"isLoggedIn":false,"isCommunityEnabled":true,"isTrackSearchImpressionEnabled":true,"isMulticatRedirectEnabled":false,"isExpandedSearchEnabled":false},"showMinimalNavForHardsell":false};
# window.GD.page.headerPageId = "explore";
# window.GD.page.userRegistrationData = {"contactUrl":"https://help.glassdoor.com/ContactUs/en_US/","enableNPI":false,"enableAddNewEmployer":false,"_enabled":true,"shouldAutoPromptCommunityReg":false,"isPageEligibleForContentLock":false};
# window.GD.page.footerData = {"introText":"","copyrightTextKey":"msg.footer.min.text","jsonString":"{\"mainMenu\":[{\"link\":\"\",\"textKey\":\"label.glassdoor\",\"childNavigationLinks\":[{\"link\":\"https://www.glassdoor.com/about/\",\"textKey\":\"link.label.aboutus.nolegal\",\"target\":\"_blank\",\"analyticsLabel\":\"site footer About press\",\"testLabel\":\"footer-about-press-link\"},{\"link\":\"https://www.glassdoor.com/blog/\",\"textKey\":\"link.label.gd-blog\",\"target\":\"_top\",\"analyticsLabel\":\"site footer Blog\",\"testLabel\":\"footer-blog-link\"},{\"link\":\"https://help.glassdoor.com/ContactUs/en_US/\",\"textKey\":\"link.label.contact-us\",\"target\":\"_blank\",\"analyticsLabel\":\"site footer Contact us\",\"testLabel\":\"footer-contact-us-link\"},{\"link\":\"https://help.glassdoor.com/s/article/Grievance-Officer-India?language=en_US\",\"textKey\":\"link.label.grievanceOfficer.legal\",\"target\":\"_blank\",\"analyticsLabel\":\"site footer Grievance Officer\",\"testLabel\":\"footer-grievance-link\"}]},{\"link\":\"\",\"textKey\":\"label.employers\",\"childNavigationLinks\":[{\"link\":\"https://www.glassdoor.co.in/employers/sign-up/?src=gdfoot\",\"textKey\":\"link.label.talent.solutions\",\"target\":\"_top\",\"rel\":\"nofollow\",\"analyticsLabel\":\"site footer Get a Free Employer Account\",\"testLabel\":\"footer-employer-account-link\"},{\"link\":\"/employers/ec/index.htm\",\"textKey\":\"link.label.employer.center\",\"target\":\"_top\",\"rel\":\"nofollow\",\"analyticsLabel\":\"site footer Employer Center\",\"testLabel\":\"footer-employer-center-link\"}]},{\"link\":\"\",\"textKey\":\"label.information\",\"childNavigationLinks\":[{\"link\":\"https://help.glassdoor.com\",\"textKey\":\"link.label.help-center\",\"target\":\"_blank\",\"analyticsLabel\":\"site footer Help\",\"testLabel\":\"footer-help-link\"},{\"link\":\"https://help.glassdoor.com/article/Community-Guidelines/en_US\",\"textKey\":\"link.label.guidelines\",\"target\":\"_blank\",\"analyticsLabel\":\"site footer guidelines\",\"testLabel\":\"footer-guidelines-link\"},{\"link\":\"/about/terms/\",\"textKey\":\"link.label.terms\",\"target\":\"_top\",\"rel\":\"nofollow\",\"analyticsLabel\":\"site footer terms of use\",\"testLabel\":\"footer-terms-of-use-link\"},{\"link\":\"https://hrtechprivacy.com/brands/glassdoor#privacypolicy\",\"textKey\":\"link.label.privacy.choices\",\"target\":\"_top\",\"rel\":\"nofollow\",\"analyticsLabel\":\"site footer privacy ad choices\",\"testLabel\":\"footer-privacy-choices-link\"},{\"link\":\"/about/doNotSell.htm\",\"textKey\":\"link.label.ccpa\",\"analyticsLabel\":\"site footer do not sell\",\"testLabel\":\"footer-do-not-sell-link\"},{\"link\":\"#\",\"id\":\"CookieConsentToolLink\",\"textKey\":\"link.label.cookieConsentTool\",\"analyticsLabel\":\"site footer cookie consent tool\",\"testLabel\":\"footer-cookie-consent-link\"}]},{\"link\":\"\",\"textKey\":\"label.work.with.us\",\"childNavigationLinks\":[{\"textKey\":\"link.label.advertisers\",\"rel\":\"nofollow\",\"testLabel\":\"footer-advertisers-link\",\"target\":\"_blank\",\"link\":\"https://www.glassdoor.com/post-job/\",\"analyticsLabel\":\"site footer advertisers\"},{\"link\":\"/Jobs/Glassdoor-Jobs-E100431.htm\",\"textKey\":\"link.label.careers\",\"target\":\"_top\",\"rel\":\"nofollow\",\"analyticsLabel\":\"site footer careers\",\"testLabel\":\"footer-careers-link\"}]}],\"socialMenu\":[{\"link\":\"/glassdoor\",\"textKey\":\"\",\"iconKey\":\"glassdoor\",\"target\":\"_top\",\"analyticsLabel\":\"site footer Glassdoor homepage\",\"testLabel\":\"footer-social-glassdoor-link\"},{\"link\":\"https://www.facebook.com/Glassdoor/\",\"textKey\":\"\",\"iconKey\":\"facebook\",\"target\":\"_blank\",\"analyticsLabel\":\"site footer facebook\",\"testLabel\":\"footer-social-facebook-link\"},{\"link\":\"https://twitter.com/Glassdoor\",\"textKey\":\"\",\"iconKey\":\"twitter\",\"target\":\"_blank\",\"analyticsLabel\":\"site footer twitter\",\"testLabel\":\"footer-social-twitter-link\"},{\"link\":\"h ...
# window.GD.page.isWebviewNative = undefined;
# window.GD.coreI18nTranslation = {"_":"","footer":{"msg.footer.text":"Glassdoor has millions of jobs plus salary information, company reviews, and interview questions from people on the inside making it easy to find a job that’s right for you.","msg.footer.min.text":"Copyright [copyright] 2008[dash][year], Glassdoor LLC. \"Glassdoor\" and logo are registered trademarks of Glassdoor LLC.","msg.footer.blog-intro":"Glassdoor’s Blog provides valuable content to the conscious job seeker and employees who are passionate about furthering and deepening their careers.","label.glassdoor":"Glassdoor","label.employers":"Employers","label.community":"Community","label.information":"Information","label.work.with.us":"Work With Us","link.label.aboutus.nolegal":"About / Press","link.label.aboutus.alternative":"About Us","link.label.aboutus.legal":"About Us & Legal Notice","link.label.careers":"Careers","link.label.widgets":"Glassdoor Widgets","link.label.feedback":"Feedback","link.label.talent.solutions":"Get a FREE Employer Account","link.label.freeEmployerAccount":"Free Employer Account","link.label.employer.center":"Employer Centre","link.label.post.job":"Post a Job","link.label.help.faq":"Help / FAQ","link.label.help-center":"Help","link.label.guidelines":"Guidelines","link.label.privacy.cookies":"Privacy & Cookies","link.label.privacy.cookies.new":"Privacy & Cookies (New)","link.label.privacy.choices":"Privacy and Ad Choices","link.label.privacy.choices.new":"Privacy and Ad Choices (New)","link.label.privacy.center":"Privacy Centre","link.label.privacy.center.new":"Privacy Centre (New)","link.label.ccpa":"Do Not Sell Or Share My Information","link.label.cookieConsentTool":"Cookie Consent Tool","link.label.privacy":"Privacy","link.label.terms":"Terms of Use","link.label.terms.new":"Terms of Use (New)","link.label.job.boards":"Job Boards","link.label.advertisers":"Advertisers","link.label.developers":"Developers","link.label.glassdoor.research":"Research","link.label.glassdoor.economicResearch":"Economic Research","link.label.glassdoor.aboutus":"About / Press","link.label.about.glassdoor":"About Glassdoor","link.label.executive":"Executive Team","link.label.events.conferences":"Events & Conferences","link.label.connect.with.us":"Connect with Us","link.label.employer.branding":"Employer Branding","link.label.employer.brand-solutions":"Employer Brand Solutions","link.label.employer.blog":"Employers Blog","link.label.recruit.engineers":"Recruit Engineers","link.label.retail.recruiting":"Retail Recruiting","link.label.innovation-lab":"Innovation Lab","link.label.sales":"Talk to Sales","link.help-center-domain":"https://help.glassdoor.com/GlassDoorHome/en_US","link.label.impressum.legal":"Imprint","link.label.grievanceOfficer.legal":"Grievance Officer - India","link.label.guides":"Guides","link.label.career-guides":"Career Guides","link.label.editorial-team":"Editorial Team","link.label.more-from-glassdoor":"More from Glassdoor","link.label.best-places-to-work":"Best Places to Work","link.label.top-ceos":"Top CEOs","link.label.fishbowl-by-glassdoor":"Fishbowl by Glassdoor","link.label.covid-resources":"COVID-19 Resources","link.label.land-the-right-job":"Land the Right Job","link.label.gender-pay-gap-breakdown":"The Gender Pay Gap Breakdown","link.label.icon":"[iconName] icon","link.label.icon.opens-in-new-window":"[iconName] icon, opens in new window","footer.appstore-cta.download-text":"Download the App","footer.glassdoorLogo":"Glassdoor Logo","footer.form.label.country":"Choose a Country","site.directory.salaries.by.job":"Salaries by Job","site.directory.salaries.by.company":"Salaries by Company","site.directory.salaries.by.city":"Salaries by City","site.directory.reviews.by.company":"Reviews by Company","site.directory.interview.questions.by.job":"Interview Questions by Job","site.directory.interviews.by.company":"Interviews by Company","site.directory.benefits.by.company":"Benefits by Company","site.directory.jobs.by.title":"Jobs by Title", ...
# window.GD.page.garnishManifest = {"403":{"js":"/garnish/static/js/gd-403.bundle.7c491.js"},"runtime":{"js":"/garnish/static/js/gd-runtime.bundle.d74e2.js"},"vendor":{"css":"/garnish/static/css/gd-vendor.bundle.1a1c4.css","js":"/garnish/static/js/gd-vendor.bundle.b5910.js"},"12mgtg-thankyou-modal":{"js":"/garnish/static/js/gd-12mgtg-thankyou-modal.bundle.3910c.js"},"alertMessage":{"js":"/garnish/static/js/gd-alertMessage.bundle.d483c.js"},"blcBanner":{"js":"/garnish/static/js/gd-blcBanner.bundle.c1cc8.js"},"bptwBanner":{"js":"/garnish/static/js/gd-bptwBanner.bundle.25ce6.js"},"community-registration-auto-prompt":{"js":"/garnish/static/js/gd-community-registration-auto-prompt.bundle.f9bca.js"},"core":{"css":"/garnish/static/css/gd-core.bundle.6cc45.css","js":"/garnish/static/js/gd-core.bundle.0d700.js"},"employersGlobalNav":{"css":"/garnish/static/css/gd-employersGlobalNav.bundle.33f42.css","js":"/garnish/static/js/gd-employersGlobalNav.bundle.83a3a.js"},"footer":{"js":"/garnish/static/js/gd-footer.bundle.9af63.js"},"globalNav":{"css":"/garnish/static/css/gd-globalNav.bundle.33f42.css","js":"/garnish/static/js/gd-globalNav.bundle.f4adc.js"},"lockedGlobalNav":{"css":"/garnish/static/css/gd-lockedGlobalNav.bundle.33f42.css","js":"/garnish/static/js/gd-lockedGlobalNav.bundle.83007.js"},"minimalGlobalNav":{"css":"/garnish/static/css/gd-minimalGlobalNav.bundle.06591.css","js":"/garnish/static/js/gd-minimalGlobalNav.bundle.fe078.js"},"nextCore":{"css":"/garnish/static/css/gd-nextCore.bundle.6cc45.css","js":"/garnish/static/js/gd-nextCore.bundle.d0c07.js"},"partnerCenterCore":{"css":"/garnish/static/css/gd-partnerCenterCore.bundle.5eddd.css","js":"/garnish/static/js/gd-partnerCenterCore.bundle.5e243.js"},"partnerCenterFooter":{"css":"/garnish/static/css/gd-partnerCenterFooter.bundle.37fdd.css","js":"/garnish/static/js/gd-partnerCenterFooter.bundle.baa01.js"},"partnerCenterHeader":{"css":"/garnish/static/css/gd-partnerCenterHeader.bundle.daa9e.css","js":"/garnish/static/js/gd-partnerCenterHeader.bundle.4be59.js"},"skipToLinks":{"js":"/garnish/static/js/gd-skipToLinks.bundle.f375d.js"},"sw-register":{"js":"/garnish/static/js/gd-sw-register.bundle.5c260.js"},"userAlert":{"js":"/garnish/static/js/gd-userAlert.bundle.c01fc.js"},"job-alert-inline-v2":{"css":"/garnish/static/css/gd-job-alert-inline-v2.bundle.css?v=2249d","js":"/garnish/static/js/gd-job-alert-inline-v2.bundle.js?v=edb8a"},"job-alert-inline":{"css":"/garnish/static/css/gd-job-alert-inline.bundle.css?v=f9b81","js":"/garnish/static/js/gd-job-alert-inline.bundle.js?v=f4cbc"},"user-hardsell-overlay":{"css":"/garnish/static/css/gd-user-hardsell-overlay.bundle.css?v=60609","js":"/garnish/static/js/gd-user-hardsell-overlay.bundle.js?v=b77de"},"user-login-all":{"css":"/garnish/static/css/gd-user-login-all.bundle.css?v=ea1ab","js":"/garnish/static/js/gd-user-login-all.bundle.js?v=ce7c5"},"user-login-community":{"css":"/garnish/static/css/gd-user-login-community.bundle.css?v=1caa8","js":"/garnish/static/js/gd-user-login-community.bundle.js?v=7ebd7"},"user-login-fishbowl-co-reg":{"css":"/garnish/static/css/gd-user-login-fishbowl-co-reg.bundle.css?v=93168","js":"/garnish/static/js/gd-user-login-fishbowl-co-reg.bundle.js?v=0154d"},"user-login":{"css":"/garnish/static/css/gd-user-login.bundle.css?v=88ec6","js":"/garnish/static/js/gd-user-login.bundle.js?v=e31df"},"user-registration-hardsell":{"css":"/garnish/static/css/gd-user-registration-hardsell.bundle.css?v=b1d11","js":"/garnish/static/js/gd-user-registration-hardsell.bundle.js?v=d18fe"},"user-registration":{"css":"/garnish/static/css/gd-user-registration.bundle.css?v=0151c","js":"/garnish/static/js/gd-user-registration.bundle.js?v=1fdd8"},"user-unvalidated":{"css":"/garnish/static/css/gd-user-unvalidated.bundle.css?v=a1821","js":"/garnish/static/js/gd-user-unvalidated.bundle.js?v=8f1f6"},"bannerAppInstall-translation-de-AT":{"js":"/garnish/static/js/gd-bannerAppInstall-translation-de-AT.bundle.js?v=70662"},"bannerAppInstall-translation- ...
# window.GD.page.alertMessageData = {};
# window.GD.page.userLogin.disableFacebookLogin = false
# </script><script nonce="">
# window.addEventListener('load', function() {
#     let gdToken = window.GD.page.gdToken;
#     if (!gdToken) gdToken = window.appCache?.initialState?.token;
#     if (!gdToken) gdToken = window.__NEXT_DATA__?.props?.pageProps?.token;
#     if(gdToken && new Date().getTime() - (sessionStorage['js-session-valid'] || 0) > 45 * 60 * 1000) {
#         sessionStorage['js-session-valid'] = new Date().getTime();
#         const req = new XMLHttpRequest();
#         req.open('POST', '/util/ajax/bwl.htm');
#         req.setRequestHeader('Content-Type', 'application/x-www-form-urlencoded');
#         req.send('guid=' + encodeURIComponent(getGdGlobals().page.guid) + '&gdToken=' + encodeURIComponent(gdToken));
#     }
# });</script><div>
# <script defer="" src="/garnish/static/js/gd-alertMessage.bundle.d483c.js"></script><script defer="" src="/garnish/static/js/gd-blcBanner.bundle.c1cc8.js"></script><script defer="" src="/garnish/static/js/gd-bptwBanner.bundle.25ce6.js"></script><script defer="" src="/garnish/static/js/gd-footer.bundle.9af63.js"></script><script defer="" src="/garnish/static/js/gd-globalNav.bundle.f4adc.js"></script><script defer="" src="/garnish/static/js/gd-skipToLinks.bundle.f375d.js"></script><script defer="" src="/garnish/static/js/gd-userAlert.bundle.c01fc.js"></script>
# </div>
# <script defer="" src="/explore/static/js/gd-vendor.bundle.29279.js" type="text/javascript"></script><script defer="" src="/explore/static/js/gd-companyExplorer.bundle.29279.js" type="text/javascript"></script></body></html>

# %%
company_name = []
for comapny in bsobj.findAll('h2', {'data-test': 'employer-short-name'}):
    company_name.append(comapny.text)

company_name
# Out:
# ['Tata Consultancy Services',
#  'Accenture',
#  'Infosys',
#  'Amazon',
#  'Cognizant Technology Solutions',
#  'Deloitte',
#  'Capgemini',
#  'IBM',
#  'Wipro',
#  'EY']
